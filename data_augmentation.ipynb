# %% [markdown]
# <a href="https://colab.research.google.com/github/Kzis/DL/blob/master/data_augmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from matplotlib.pyplot import imread, imshow, subplots, show , imsave

# %%
def plot(data_generator):
    """
    Plots 4 images generated by an object of the ImageDataGenerator class.
    """
    data_generator.fit(images)
    image_iterator = data_generator.flow(images)
    
    # Plot the images given by the iterator
    fig, rows = subplots(nrows=1, ncols=4, figsize=(18,18))
    for row in rows:
        row.imshow(image_iterator.next()[0].astype('int'))
        row.axis('off')
    show()

# %%
# Read image all directory
import glob
for img in glob.glob("xxx/*.png"):
    image = imread(img)
    images = image.reshape((1, image.shape[0], image.shape[1], image.shape[2]))
    imshow(images[0])
    show()

# %%
image = imread("home.jpg")

# Creating a dataset which contains just one image.
images = image.reshape((1, image.shape[0], image.shape[1], image.shape[2]))

imshow(images[0])
show()

# %%
# Save image
path = 'xxx'
filename = 'test'
format='.png'
imsave(path+'/'+filename+format, image)

# %%
# 1. Rotation
data_generator = ImageDataGenerator(rotation_range=90)
plot(data_generator)

# %%
# 2. Width Shifting
data_generator = ImageDataGenerator(width_shift_range=0.3)
plot(data_generator)

# %%
# 3. Height Shifting
data_generator = ImageDataGenerator(height_shift_range=0.3)
plot(data_generator)

# %%
# 4. Brightness
data_generator = ImageDataGenerator(brightness_range=(0.1, 0.9))
plot(data_generator)

# %%
# 5. Shear Intensity
data_generator = ImageDataGenerator(shear_range=45.0)
plot(data_generator)

# %%
# 6. Zoom
data_generator = ImageDataGenerator(zoom_range=[0.5, 1.5])
plot(data_generator)

# %%
# 7. Channel Shift
data_generator = ImageDataGenerator(channel_shift_range=150.0)
plot(data_generator)

# %%
# 8. Horizontal Flip
data_generator = ImageDataGenerator(horizontal_flip=True)
plot(data_generator)

# %%
# 9. Vertical Flip
data_generator = ImageDataGenerator(vertical_flip=True)
plot(data_generator)
